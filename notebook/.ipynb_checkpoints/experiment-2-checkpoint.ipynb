# %% [markdown]
# ## ウ音便
#
# * 子音が落ちる
#     * katta じゃなくて今度は kauta がベストになれば面白い。で、欲を言えば koota も出てほしい
# * 調音結合
# * 子音が落ちるか母音が落ちるか。
# * ウ音便だけ再現できない。
#     * さらにauがoとなるような変化が必要。
#     * 産出時の調音結合。
#     * 2dを見るとaとuの中間のとき、最も近いのはoになる。
#     * これは考察行きでいい。完璧は無理
#
# 母音を削るか、子音を削るか、話者の知識なのか、ノイズなのか。

# %%
import sys
sys.path.append('..')

# %%
# %load_ext autoreload
# %autoreload 2

from hydra.experimental import initialize, compose
from src.agent import Agent
# https://hydra.cc/docs/next/experimental/compose_api

with initialize(config_path="../hyparam"):
    config = compose(config_name="config.yml")
agent_sample = Agent(config)
agent_sample.poisson_params
# Out:
# array([9, 9, 9, 3, 3, 3, 9], dtype=object)

# %%
from src.agent import Agent
from hydra.experimental import initialize, compose
from itertools import product
import numpy as np
from collections import Counter
from joblib import Parallel, delayed


trial = list(range(20))
w_durations = [0, 1, 2, 3]
intrinsic = ["production", "update"]
n_iter = list(range(20))

def perception(prod, perc, symbol):
    phoneme, obs, states = prod.production("kawuta")
    obs = np.array(obs).astype('double')
    phoneme_hat, obs, states_hat = perc.perception(obs)
    if phoneme_hat == "kota":  # TODO: 二重母音のkotaが識別できないので修正. perceptionメソッドの修正で対応すべき
        phoneme_hat = "koota"
    return phoneme_hat

results_list = []
for t in trial:
    if t % 5 == 0:
        print(f"trial: {t}")
    for w_duration, switch in product(w_durations, intrinsic):
        with initialize(config_path="../hyparam"):
            config_prod = compose(config_name="config.yml", overrides=[f"w_duration={w_duration}"])
        a = Agent(config_prod)
        if switch == "production":
            with initialize(config_path="../hyparam"):
                config_perc = compose(config_name="config.yml")
            b = Agent(config_perc)
        elif switch == "update":
            b = Agent(config)
        else:
            raise ValueError

        perceptions = Parallel(n_jobs=-1)(delayed(perception)(prod=a, perc=b, symbol="kawuta") for n in n_iter)

        results_list.append({
            "trial": t,
            "w_duration": w_duration,  # TODO: 同上
            "intrinsic": switch,
            "n_kawuta": perceptions.count("kawuta"),
            "n_kawta": perceptions.count("kawta"),
            "n_kaQta": perceptions.count("kaQta"),
            "n_kauta": perceptions.count("kauta"),
            "n_koota": perceptions.count("koota"),
            "counter": Counter(perceptions),
        })
        print(Counter(perceptions))
# Out:
# trial: 0
# Counter({'kauta': 19, 'tauta': 1})
# Counter({'kauta': 20})
# Counter({'kawuta': 11, 'kauta': 9})
# Counter({'kauta': 15, 'kawuta': 5})
# Counter({'kawuta': 17, 'kauta': 3})
# Counter({'kawuta': 18, 'kauta': 1, 'tawuta': 1})
# Counter({'kawuta': 18, 'kawutua': 1, 'kauta': 1})
# Counter({'kawuta': 19, 'kawutau': 1})
# Counter({'kauta': 17, 'tauta': 2, 'kautau': 1})
# Counter({'kauta': 17, 'kautau': 1, 'kawuta': 1, 'kauka': 1})
# Counter({'kauta': 12, 'kawuta': 8})
# Counter({'kauta': 11, 'kawuta': 7, 'kawuka': 1, 'tawuata': 1})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 17, 'kauta': 2, 'kawutao': 1})
# Counter({'kawuta': 20})
# Counter({'kawuta': 18, 'kauta': 1, 'kawuka': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 17, 'kauka': 1, 'kawuta': 1, 'kautao': 1})
# Counter({'kawuta': 10, 'kauta': 9, 'kauka': 1})
# Counter({'kauta': 15, 'kawuta': 4, 'kawuka': 1})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 19, 'tawuta': 1})
# Counter({'kawuta': 18, 'kauta': 1, 'kawuka': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 20})
# Counter({'kauta': 10, 'kawuta': 10})
# Counter({'kawuta': 12, 'kauta': 8})
# Counter({'kawuta': 16, 'kauta': 3, 'kawuka': 1})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kauta': 18, 'kauka': 1, 'kautau': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 13, 'kawuta': 7})
# Counter({'kawuta': 14, 'kauta': 6})
# Counter({'kawuta': 17, 'kauta': 2, 'tawuta': 1})
# Counter({'kawuta': 18, 'kawutao': 1, 'kauta': 1})
# Counter({'kawuta': 19, 'tawuta': 1})
# Counter({'kawuta': 19, 'kawutau': 1})
# trial: 5
# Counter({'kauta': 20})
# Counter({'kauta': 19, 'kauka': 1})
# Counter({'kauta': 11, 'kawuta': 9})
# Counter({'kauta': 10, 'kawuta': 8, 'kawuka': 1, 'tawuta': 1})
# Counter({'kawuta': 17, 'kauta': 3})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 20})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 20})
# Counter({'kawuta': 9, 'kauta': 8, 'kawutau': 1, 'kautao': 1, 'kauka': 1})
# Counter({'kauta': 11, 'kawuta': 9})
# Counter({'kawuta': 16, 'kauta': 4})
# Counter({'kawuta': 18, 'kauta': 1, 'kawutau': 1})
# Counter({'kawuta': 19, 'tawuta': 1})
# Counter({'kawuta': 20})
# Counter({'kauta': 20})
# Counter({'kauta': 20})
# Counter({'kauta': 9, 'kawuta': 9, 'tawuta': 1, 'kawutau': 1})
# Counter({'kauta': 12, 'kawuta': 7, 'kautao': 1})
# Counter({'kawuta': 18, 'kauta': 1, 'tawuta': 1})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 20})
# Counter({'kawuta': 16, 'kauta': 3, 'tawuta': 1})
# Counter({'kauta': 19, 'kauka': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 10, 'kawuta': 10})
# Counter({'kauta': 11, 'kawuta': 9})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 19, 'tawuta': 1})
# Counter({'kauta': 19, 'kautao': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 12, 'kawuta': 8})
# Counter({'kauta': 10, 'kawuta': 8, 'kawutau': 1, 'kawutawa': 1})
# Counter({'kawuta': 17, 'kauta': 3})
# Counter({'kawuta': 16, 'kauta': 4})
# Counter({'kawuta': 16, 'tawuta': 2, 'kauta': 2})
# Counter({'kawuta': 19, 'kauta': 1})
# trial: 10
# Counter({'kauta': 20})
# Counter({'kauta': 20})
# Counter({'kauta': 13, 'kawuta': 7})
# Counter({'kauta': 16, 'kawuta': 3, 'tawuta': 1})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 14, 'kauta': 6})
# Counter({'kawuta': 20})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kauta': 19, 'kautao': 1})
# Counter({'kauta': 20})
# Counter({'kawuta': 11, 'kauta': 9})
# Counter({'kauta': 11, 'kawuta': 8, 'tauta': 1})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 17, 'kauta': 3})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 20})
# Counter({'kauta': 20})
# Counter({'kauta': 20})
# Counter({'kawuta': 12, 'kauta': 8})
# Counter({'kawuta': 11, 'kauta': 8, 'tauta': 1})
# Counter({'kawuta': 17, 'kauta': 3})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 20})
# Counter({'kawuta': 20})
# Counter({'kauta': 20})
# Counter({'kauta': 17, 'kautao': 2, 'kawuta': 1})
# Counter({'kawuta': 10, 'kauta': 10})
# Counter({'kawuta': 11, 'kauta': 6, 'kautao': 1, 'kauka': 1, 'kawuka': 1})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 18, 'kauta': 1, 'kawuka': 1})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 18, 'kawutau': 1, 'kauta': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 19, 'kawuta': 1})
# Counter({'kauta': 12, 'kawuta': 8})
# Counter({'kauta': 12, 'kawuta': 7, 'tawuta': 1})
# Counter({'kawuta': 15, 'kauta': 3, 'tawuta': 2})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 18, 'kawutau': 1, 'kauta': 1})
# Counter({'kawuta': 20})
# trial: 15
# Counter({'kauta': 20})
# Counter({'kauta': 18, 'tauta': 1, 'kautao': 1})
# Counter({'kawuta': 13, 'kauta': 7})
# Counter({'kauta': 15, 'kawuta': 5})
# Counter({'kawuta': 16, 'kauta': 3, 'kawutau': 1})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 20})
# Counter({'kawuta': 19, 'kawuka': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 19, 'kautau': 1})
# Counter({'kauta': 10, 'kawuta': 8, 'kawuka': 1, 'tawuta': 1})
# Counter({'kauta': 13, 'kawuta': 7})
# Counter({'kawuta': 16, 'kauta': 4})
# Counter({'kawuta': 16, 'kauta': 4})
# Counter({'kawuta': 17, 'kauta': 1, 'tawuta': 1, 'kawuka': 1})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kauta': 20})
# Counter({'kauta': 20})
# Counter({'kauta': 10, 'kawuta': 10})
# Counter({'kawuta': 10, 'kauta': 9, 'kawuka': 1})
# Counter({'kawuta': 19, 'kauta': 1})
# Counter({'kawuta': 16, 'tawuta': 2, 'kawuka': 1, 'kauta': 1})
# Counter({'kawuta': 18, 'kawuka': 1, 'tawuta': 1})
# Counter({'kawuta': 20})
# Counter({'kauta': 20})
# Counter({'kauta': 19, 'kauka': 1})
# Counter({'kawuta': 11, 'kauta': 8, 'kawutao': 1})
# Counter({'kawuta': 11, 'kauta': 9})
# Counter({'kawuta': 14, 'kauta': 6})
# Counter({'kawuta': 17, 'kauta': 3})
# Counter({'kawuta': 18, 'kawuka': 1, 'kawutao': 1})
# Counter({'kawuta': 20})
# Counter({'kauta': 18, 'kawuta': 1, 'kautau': 1})
# Counter({'kauta': 17, 'kauka': 2, 'kautao': 1})
# Counter({'kauta': 11, 'kawuta': 9})
# Counter({'kauta': 10, 'kawuta': 9, 'kautao': 1})
# Counter({'kawuta': 15, 'kauta': 5})
# Counter({'kawuta': 18, 'kauta': 2})
# Counter({'kawuta': 20})
# Counter({'kawuta': 19, 'tauta': 1})

# %%
import pandas as pd
results = pd.DataFrame(results_list)

# %%
results
# Out:
#      trial  w_duration   intrinsic  n_kawuta  n_kawta  n_kaQta  n_kauta  \
# 0        0           0  production         0        0        0       19
# 1        0           0      update         0        0        0       20
# 2        0           1  production        11        0        0        9
# 3        0           1      update         5        0        0       15
# 4        0           2  production        17        0        0        3
# ..     ...         ...         ...       ...      ...      ...      ...
# 155     19           1      update         9        0        0       10
# 156     19           2  production        15        0        0        5
# 157     19           2      update        18        0        0        2
# 158     19           3  production        20        0        0        0
# 159     19           3      update        19        0        0        0
#
#      n_koota                                  counter
# 0          0                {'kauta': 19, 'tauta': 1}
# 1          0                            {'kauta': 20}
# 2          0               {'kauta': 9, 'kawuta': 11}
# 3          0               {'kawuta': 5, 'kauta': 15}
# 4          0               {'kawuta': 17, 'kauta': 3}
# ..       ...                                      ...
# 155        0  {'kauta': 10, 'kawuta': 9, 'kautao': 1}
# 156        0               {'kauta': 5, 'kawuta': 15}
# 157        0               {'kawuta': 18, 'kauta': 2}
# 158        0                           {'kawuta': 20}
# 159        0               {'kawuta': 19, 'tauta': 1}
#
# [160 rows x 9 columns]

# %%
# 分析は results.md の
intrinsic = results[["trial", "w_duration", "intrinsic", "n_kawuta", "n_kawta","n_kaQta", "n_kauta", "n_koota"]]
intrinsic.to_csv('../data/w_intrinsic.csv', index=False)
intrinsic.head()
# Out:
#    trial  w_duration   intrinsic  n_kawuta  n_kawta  n_kaQta  n_kauta  n_koota
# 0      0           0  production         0        0        0       19        0
# 1      0           0      update         0        0        0       20        0
# 2      0           1  production        11        0        0        9        0
# 3      0           1      update         5        0        0       15        0
# 4      0           2  production        17        0        0        3        0

# %%
def flatten_dict(count_i):
    flat = []
    count_dict_i = dict(count_i)
    for k, v in count_dict_i.items():
        flat += [k]*v
    return flat

# %%
recognized = []
for cound_dict in results.counter.to_numpy():
    recognized += flatten_dict(cound_dict)

len(recognized) # 100*900 だから
# Out:
# 3200

# %%
# https://stackoverflow.com/questions/31111032/transform-a-counter-object-into-a-pandas-dataframe
d = dict(Counter(recognized))
df = pd.DataFrame.from_dict(d, orient='index').reset_index()
candidate = df.rename(columns={'index': 'candidate', 0:'count'})
candidate.to_csv('../data/w_candidate.csv', index=False)
